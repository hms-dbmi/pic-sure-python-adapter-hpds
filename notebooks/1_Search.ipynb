# %%
import picsure

# %%
token_file = "token.txt"

with open(token_file, "r") as f:
    my_token = f.read()

# %%
authorized_session = picsure.connect(
    picsure.Platform.BDC_AUTHORIZED,
    my_token
)
# Out:
# You're successfully connected to BDC Authorized as user george_colon@era.nih.gov!
# Your token expires on 2026-06-13T14:40:16Z.

# %%
authorized_session.searchDictionary("age")
# Out:
#                                             conceptPath                  name  \
# 0     \phs000179\pht002239\phv00169388\Duration_Smok...           phv00169388
# 1                      \phs002907\AGE_C4R_BASELINE_BDC\  AGE_C4R_BASELINE_BDC
# 2             \phs000200\pht001000\phv00078662\AGEFBIR\           phv00078662
# 3              \phs000007\pht000395\phv00056587\age_s1\           phv00056587
# 4              \phs000007\pht000397\phv00056723\age_s2\           phv00056723
# ...                                                 ...                   ...
# 4483          \phs000007\pht000676\phv00066827\system1\           phv00066827
# 4484         \phs000007\pht000676\phv00066823\phrm_gp2\           phv00066823
# 4485          \phs000007\pht000676\phv00066833\MEDNAME\           phv00066833
# 4486            \phs000007\pht005141\phv00254644\fv057\           phv00254644
# 4487  \phs000179\pht002239\phv00569411\ptoa_surgothe...           phv00569411
#
#                                     display  \
# 0                          Duration_Smoking
# 1     Age at C4R baseline (Marchh 01, 2020)
# 2                                   AGEFBIR
# 3                                    age_s1
# 4                                    age_s2
# ...                                     ...
# 4483                                system1
# 4484                               phrm_gp2
# 4485                                MEDNAME
# 4486                                  fv057
# 4487                 ptoa_surgother_specify
#
#                                             description     dataType  \
# 0                               Duration of smoking yrs   Continuous
# 1                 Age at C4R baseline (Marchh 01, 2020)   Continuous
# 2                                    Age at First Birth  Categorical
# 3                                  Age = StdyDtqa - DOB   Continuous
# 4                            Age (age = formdate - DOB)   Continuous
# ...                                                 ...          ...
# 4483  Description/Label for anatomical main group - ...  Categorical
# 4484  Description/Label for pharmacological subgroup...  Categorical
# 4485                                    Medication name  Categorical
# 4486  Medical History - Respiratory Symptoms: Do you...  Categorical
# 4487                      Knee surgery: Other - specify  Categorical
#
#         studyId                                             values   min  \
# 0     phs000179                                                 []   0.0
# 1     phs002907                                                 []  38.0
# 2     phs000200       [20-29, 30+, < 20, Never had term pregnancy]   NaN
# 3     phs000007                                                 []  29.0
# 4     phs000007                                                 []  44.0
# ...         ...                                                ...   ...
# 4483  phs000007  [ALIMENTARY TRACT AND METABOLISM, ANTIINFECTIV...   NaN
# 4484  phs000007  [ACE INHIBITORS, PLAIN, ANTACIDS, ANTIGLAUCOMA...   NaN
# 4485  phs000007  [(ANTIOXIDANT), (ETHIN. ESTRADIO, (ETHINYL EST...   NaN
# 4486  phs000007                                          [No, Yes]   NaN
# 4487  phs000179  [1989--tibial plataeu  2001--unknown knee surg...   NaN
#
#        max  allowFiltering  meta studyAcronym
# 0     78.5            True  None     COPDGENE
# 1     90.0            True  None      C4R_JHS
# 2      NaN            True  None          WHI
# 3     86.0            True  None          FHS
# 4     86.0            True  None          FHS
# ...    ...             ...   ...          ...
# 4483   NaN           False  None          FHS
# 4484   NaN           False  None          FHS
# 4485   NaN           False  None          FHS
# 4486   NaN           False  None          FHS
# 4487   NaN           False  None     COPDGENE
#
# [4488 rows x 12 columns]

# %%
authorized_session.showAllFacets()
# Out:
#         category  Category Display                        display  \
# 0     dataset_id           Dataset      RECOVER_Adult (phs003463)
# 1     dataset_id           Dataset                FHS (phs000007)
# 2     dataset_id           Dataset               ARIC (phs000280)
# 3     dataset_id           Dataset  RECOVER_Pediatric (phs003461)
# 4     dataset_id           Dataset               MESA (phs000209)
# ..           ...               ...                            ...
# 494  data_source         Data Type                        Genomic
# 495  data_source         Data Type                     Biosamples
# 496  data_source         Data Type              Electrocardiogram
# 497    data_type  Type of Variable                    Categorical
# 498    data_type  Type of Variable                     Continuous
#
#                                            description  \
# 0    Researching COVID to Enhance Recovery (RECOVER...
# 1                                    Framingham Cohort
# 2    Atherosclerosis Risk in Communities (ARIC) Cohort
# 3    Researching COVID to Enhance Recovery (RECOVER...
# 4    Multi-Ethnic Study of Atherosclerosis (MESA) S...
# ..                                                 ...
# 494                       Associated with genomic data
# 495                     Associated with biosample data
# 496             Associated with electrocardiogram data
# 497
# 498
#
#                              value   count
# 0                        phs003463  160676
# 1                        phs000007   54985
# 2                        phs000280   26106
# 3                        phs003461   20680
# 4                        phs000209   20086
# ..                             ...     ...
# 494            data_source_genomic      17
# 495         data_source_biosamples       8
# 496  data_source_electrocardiogram       0
# 497                    categorical  208157
# 498                     continuous  115781
#
# [499 rows x 6 columns]

# %%
child_facet = authorized_session.facets()
child_facet.add("Consortium_Curated_Facets", '06m-post index')
child_facet.view()

authorized_session.searchDictionary("", facets=child_facet)
# Out:
#                                             conceptPath  \
# 0     \phs003463\RECOVER_Adult\biospecimens\ac_colld...
# 1     \phs003463\RECOVER_Adult\biospecimens\ac_colld...
# 2     \phs003463\RECOVER_Adult\biospecimens\ac_sampl...
# 3     \phs003463\RECOVER_Adult\biospecimens\ac_kit_d...
# 4     \phs003463\RECOVER_Adult\biospecimens\ac_kit_d...
# ...                                                 ...
# 7955  \phs003463\RECOVER_Adult\surveys\pregnancy\pre...
# 7956  \phs003463\RECOVER_Adult\surveys\pregnancy\pre...
# 7957  \phs003463\RECOVER_Adult\surveys\pregnancy\pre...
# 7958  \phs003463\RECOVER_Adult\surveys\pregnancy\pre...
# 7959  \phs003463\RECOVER_Adult\surveys\pregnancy\pre...
#
#                                       name  \
# 0                  rc-ra1:ac_colldt|inf|v6
# 1               rc-ra1:ac_colldt|noninf|v6
# 2         rc-ra1:ac_sample_kit_type|inf|v6
# 3        rc-ra1:ac_kit_date_time|noninf|v6
# 4           rc-ra1:ac_kit_date_time|inf|v6
# ...                                    ...
# 7955  rc-ra1:preg_coviddefectspec_1|inf|v6
# 7956        rc-ra1:preg_covidwtlb_1|inf|v6
# 7957     rc-ra1:preg_covidwtlb_1|noninf|v6
# 7958        rc-ra1:preg_covidnicu_1|inf|v6
# 7959     rc-ra1:preg_covidnicu_1|noninf|v6
#
#                                                 display  \
# 0     Date of Biospecimens form collection: [Infecte...
# 1     Date of Biospecimens form collection: [Non-inf...
# 2           Select Kit type:  [Infected-06m post-index]
# 3     Date and Time of Collection [Non-infected-06m ...
# 4     Date and Time of Collection [Infected-06m post...
# ...                                                 ...
# 7955  What type of birth defect did your baby have? ...
# 7956  Pounds (Weight at birth): [Infected-06m post-i...
# 7957  Pounds (Weight at birth): [Non-infected-06m po...
# 7958  Was your baby admitted to the neonatal intensi...
# 7959  Was your baby admitted to the neonatal intensi...
#
#                                             description     dataType  \
# 0     Answerdata Form: biospecimens Field: ac_colldt...  Categorical
# 1     Answerdata Form: biospecimens Field: ac_colldt...  Categorical
# 2     Answerdata Form: biospecimens Field: ac_sample...  Categorical
# 3     Answerdata Form: biospecimens Field: ac_kit_da...  Categorical
# 4     Answerdata Form: biospecimens Field: ac_kit_da...  Categorical
# ...                                                 ...          ...
# 7955  Answerdata Form: pregnancy Field: preg_covidde...  Categorical
# 7956  Answerdata Form: pregnancy Field: preg_covidwt...   Continuous
# 7957  Answerdata Form: pregnancy Field: preg_covidwt...   Continuous
# 7958  Answerdata Form: pregnancy Field: preg_covidni...  Categorical
# 7959  Answerdata Form: pregnancy Field: preg_covidni...  Categorical
#
#         studyId                                             values  min  max  \
# 0     phs003463  [2021-01-03, 2021-03-05, 2021-03-18, 2021-03-2...  NaN  NaN
# 1     phs003463  [2021-03-19, 2021-06-18, 2022-01-01, 2022-01-0...  NaN  NaN
# 2     phs003463  [ExamOne RECOVER Adult Tier 1 Mayo Kit 1 - Bas...  NaN  NaN
# 3     phs003463  [2021-03-19, 2021-06-18, 2022-01-01, 2022-01-0...  NaN  NaN
# 4     phs003463  [2021-01-03, 2021-03-05, 2021-03-18, 2021-03-2...  NaN  NaN
# ...         ...                                                ...  ...  ...
# 7955  phs003463                              [Limbs (extremities)]  NaN  NaN
# 7956  phs003463                                                 []  2.0  9.0
# 7957  phs003463                                                 []  3.0  9.0
# 7958  phs003463                                          [No, Yes]  NaN  NaN
# 7959  phs003463                                          [No, Yes]  NaN  NaN
#
#       allowFiltering  meta   studyAcronym
# 0               True  None  RECOVER_Adult
# 1               True  None  RECOVER_Adult
# 2               True  None  RECOVER_Adult
# 3               True  None  RECOVER_Adult
# 4               True  None  RECOVER_Adult
# ...              ...   ...            ...
# 7955           False  None  RECOVER_Adult
# 7956           False  None  RECOVER_Adult
# 7957           False  None  RECOVER_Adult
# 7958           False  None  RECOVER_Adult
# 7959           False  None  RECOVER_Adult
#
# [7960 rows x 12 columns]

# %%
facets = authorized_session.facets()
facets.add("dataset_id", "phs000007")
facets.view()
# Out:
# {'dataset_id': ['phs000007'],
#  'Consortium_Curated_Facets': [],
#  'common_data_elements': [],
#  'data_source': [],
#  'data_type': []}

# %%
authorized_session.searchDictionary("sex", facets=facets)
# Out:
#                                    conceptPath         name   display  \
# 0        \phs000007\pht004374\phv00253990\sex\  phv00253990       sex
# 1        \phs000007\pht007777\phv00369653\SEX\  phv00369653       SEX
# 2        \phs000007\pht016160\phv00568089\sex\  phv00568089       sex
# 3        \phs000007\pht015172\phv00549391\sex\  phv00549391       sex
# 4        \phs000007\pht016158\phv00567242\sex\  phv00567242       sex
# ..                                         ...          ...       ...
# 75  \phs000007\pht000676\phv00066829\phrm_gp1\  phv00066829  phrm_gp1
# 76   \phs000007\pht000676\phv00066827\system1\  phv00066827   system1
# 77   \phs000007\pht000676\phv00066845\system4\  phv00066845   system4
# 78   \phs000007\pht000676\phv00066821\system2\  phv00066821   system2
# 79  \phs000007\pht000676\phv00066841\ther_gp3\  phv00066841  ther_gp3
#
#                                           description     dataType    studyId  \
# 0                              Sex of the participant  Categorical  phs000007
# 1                                  Sex of participant  Categorical  phs000007
# 2                              Sex of the participant  Categorical  phs000007
# 3                              Sex of the participant  Categorical  phs000007
# 4                              Sex of the participant  Categorical  phs000007
# ..                                                ...          ...        ...
# 75  Description/Label for pharmacological subgroup...  Categorical  phs000007
# 76  Description/Label for anatomical main group - ...  Categorical  phs000007
# 77  Description/Label for anatomical main group - ...  Categorical  phs000007
# 78  Description/Label for anatomical main group - ...  Categorical  phs000007
# 79  Description/Label for therapeutic subgroup - t...  Categorical  phs000007
#
#                                                values  min  max  \
# 0                                      [Female, Male]  NaN  NaN
# 1                                      [Female, Male]  NaN  NaN
# 2                                      [Female, Male]  NaN  NaN
# 3                                      [Female, Male]  NaN  NaN
# 4                                      [Female, Male]  NaN  NaN
# ..                                                ...  ...  ...
# 75  [ACE INHIBITORS, PLAIN, ADRENERGICS FOR SYSTEM...  NaN  NaN
# 76  [ALIMENTARY TRACT AND METABOLISM, ANTIINFECTIV...  NaN  NaN
# 77  [GENITO URINARY SYSTEM AND SEX HORMONES, RESPI...  NaN  NaN
# 78  [ALIMENTARY TRACT AND METABOLISM, BLOOD AND BL...  NaN  NaN
# 79  [ANALGESICS, ANTIEPILEPTICS, ANTIHEMORRHAGICS,...  NaN  NaN
#
#     allowFiltering  meta studyAcronym
# 0             True  None          FHS
# 1             True  None          FHS
# 2             True  None          FHS
# 3             True  None          FHS
# 4             True  None          FHS
# ..             ...   ...          ...
# 75           False  None          FHS
# 76           False  None          FHS
# 77           False  None          FHS
# 78           False  None          FHS
# 79           False  None          FHS
#
# [80 rows x 12 columns]
