# %%
import picsure

# %%
token_file = "token.txt"

with open(token_file, "r") as f:
    my_token = f.read()

session = picsure.connect(
    picsure.Platform.BDC_AUTHORIZED,
    dev_mode=True,
    token=my_token
)

# %%
session.runQueryByID("ea5f32d2-2ca8-4820-a96a-41239af75d38")
