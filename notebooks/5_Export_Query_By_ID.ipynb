# %%
import picsure

# %%
token_file = "token.txt"

with open(token_file, "r") as f:
    my_token = f.read()

session = picsure.connect(
    picsure.Platform.BDC_AUTHORIZED,
    dev_mode=True,
    token=my_token
)
# Out:
# picsure.http /psama/user/me 200 202ms in=0B out=4.1KB retry=0
# picsure.http /picsure/info/resources 200 124ms in=0B out=213B retry=0
# picsure.http /psama/user/me/queryTemplate/ 200 104ms in=0B out=1.8KB retry=0
# picsure.http /picsure/proxy/dictionary-api/concepts?page_number=0&page_size=1 200 118ms in=840B out=1.2KB retry=0
# picsure.connect connect 0ms
# You're successfully connected to BDC Authorized as user george_colon@era.nih.gov!
# Your token expires on 2026-06-13T14:40:16Z.

# %%
# 17375ffe-db0d-4cd4-828c-1c240608daef
clauseGroup = session.loadQueryByID("ea5f32d2-2ca8-4820-a96a-41239af75d38")
session.runQuery(clauseGroup)
# Out:
# picsure.http /picsure/query/ea5f32d2-2ca8-4820-a96a-41239af75d38/metadata 200 120ms in=0B out=9.0KB retry=0
# picsure.fn session.loadQueryByID 123ms
# picsure.http /picsure/v3/query/sync 200 361ms in=1.1KB out=2B retry=0
# picsure.fn session.runQuery 364ms
# CountResult(value=91, margin=None, cap=None, raw='91')
